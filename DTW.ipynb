# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd
import numpy as np

# %%
a1 = "/content/A/a1.wav"
a2 = "/content/A/a2.wav"
a3 = "/content/A/a3.wav"

b1 = "/content/B/b1.wav"
b2 = "/content/B/b2.wav"
b3 = "/content/B/b3.wav"

ban1 = "/content/Ban/ban1.wav"
ban2 = "/content/Ban/ban2.wav"
ban3 = "/content/Ban/ban3.wav"

len1 = "/content/Len/len1.wav"
len2 = "/content/Len/len2.wav"
len3 = "/content/Len/len3.wav"

nhay1 = "/content/Nhay/nhay1.wav"
nhay2 = "/content/Nhay/nhay2.wav"
nhay3 = "/content/Nhay/nhay3.wav"

phai1 = "/content/Phai/phai1.wav"
phai2 = "/content/Phai/phai2.wav"
phai3 = "/content/Phai/phai3.wav"

trai1 = "/content/Trai/trai1.wav"
trai2 = "/content/Trai/trai2.wav"
trai3 = "/content/Trai/trai3.wav"

xuong1 = "/content/Xuong/xuong1.wav"
xuong2 = "/content/Xuong/xuong2.wav"
xuong3 = "/content/Xuong/xuong3.wav"

# %%
def normalize_mfcc(mfcc):
    for i in range(mfcc.shape[1]):
        mfcc[:,i] = mfcc[:,i] - np.mean(mfcc[:,i])
        mfcc[:,i] = mfcc[:,i] / np.max(np.abs(mfcc[:,i]))
    return mfcc

# %% [markdown]
# **DTW word "a"**

# %%
ipd.Audio(a1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(a2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(a3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_a1 = librosa.load(a1)[0]
lib_a2 = librosa.load(a2)[0]
lib_a3 = librosa.load(a3)[0]

# %%
template_a1 = normalize_mfcc(librosa.feature.mfcc(y=lib_a1))
template_a2 = normalize_mfcc(librosa.feature.mfcc(y=lib_a2))
template_a3 = normalize_mfcc(librosa.feature.mfcc(y=lib_a3))

# %%
metric = 'euclidean'

# %%
metric = 'cosine'

# %%
cost01_a, align01_a = librosa.sequence.dtw(template_a1, template_a2, metric=metric)
cost02_a, align02_a = librosa.sequence.dtw(template_a1, template_a3, metric=metric)

# %%
count_a = np.ones(len(template_a1[0]))

summ_a = template_a1.copy()

# %%
for pair_a in align01_a:
    t, q = pair_a
    count_a[t] += 1
    summ_a[:,t] += template_a2[:,q]

# %%
for pair_a in align02_a:
    t, q = pair_a
    count_a[t] += 1
    summ_a[:,t] += template_a3[:,q]

# %%
average_a = summ_a / count_a
average_a.shape
# Out:
# (20, 21)

# %%
average_template_a = average_a

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 0.22101310536571273

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 2.730077385469694

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 3.2835055346531368

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 2.3201747299063586

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 2.1382979706747274

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 4.3767677316965266

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 2.03279325722003

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_a, metric=metric)[0][-1,-1]
# Out:
# 7.895647442005524

# %% [markdown]
# **DTW word "b"**

# %%
ipd.Audio(b1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(b2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(b3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_b1 = librosa.load(b1)[0]
lib_b2 = librosa.load(b2)[0]
lib_b3 = librosa.load(b3)[0]

# %%
template_b1 = normalize_mfcc(librosa.feature.mfcc(y=lib_b1))
template_b2 = normalize_mfcc(librosa.feature.mfcc(y=lib_b2))
template_b3 = normalize_mfcc(librosa.feature.mfcc(y=lib_b3))

# %%
cost01_b, align01_b = librosa.sequence.dtw(template_b1, template_b2, metric=metric)
cost02_b, align02_b = librosa.sequence.dtw(template_b1, template_b3, metric=metric)

# %%
count_b = np.ones(len(template_b1[0]))

summ_b = template_b1.copy()

# %%
for pair_b in align01_b:
    t, q = pair_b
    count_b[t] += 1
    summ_b[:,t] += template_b2[:,q]

# %%
for pair_b in align02_b:
    t, q = pair_b
    count_b[t] += 1
    summ_b[:,t] += template_b3[:,q]

# %%
average_b = summ_b / count_b
average_b.shape
# Out:
# (20, 20)

# %%
average_template_b = average_b

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 3.1909684077722247

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 0.16051159145002825

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 2.897153661626037

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 0.6196499430599551

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 1.408171364273953

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 5.084693523293791

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 3.17248819963551

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_b, metric=metric)[0][-1,-1]
# Out:
# 5.611577511222647

# %% [markdown]
# **DTW word "ban"**

# %%
ipd.Audio(ban1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(ban2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(ban3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_ban1 = librosa.load(ban1)[0]
lib_ban2 = librosa.load(ban2)[0]
lib_ban3 = librosa.load(ban3)[0]

# %%
template_ban1 = normalize_mfcc(librosa.feature.mfcc(y=lib_ban1))
template_ban2 = normalize_mfcc(librosa.feature.mfcc(y=lib_ban2))
template_ban3 = normalize_mfcc(librosa.feature.mfcc(y=lib_ban3))

# %%
cost01_ban, align01_ban = librosa.sequence.dtw(template_ban1, template_ban2, metric=metric)
cost02_ban, align02_ban = librosa.sequence.dtw(template_ban1, template_ban3, metric=metric)

# %%
count_ban = np.ones(len(template_ban1[0]))

summ_ban = template_ban1.copy()

# %%
for pair_ban in align01_ban:
    t, q = pair_ban
    count_ban[t] += 1
    summ_ban[:,t] += template_ban2[:,q]

# %%
for pair_ban in align02_ban:
    t, q = pair_ban
    count_ban[t] += 1
    summ_ban[:,t] += template_ban3[:,q]

# %%
average_ban = summ_ban / count_ban
average_ban.shape
# Out:
# (20, 16)

# %%
average_template_ban = average_ban

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 3.4807181016535953

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 2.418657042894835

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 0.05998955510273407

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 2.8633695872616927

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 1.4783320958093886

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 1.3339072637302145

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 2.0423030721793705

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_ban, metric=metric)[0][-1,-1]
# Out:
# 3.08648153178172

# %% [markdown]
# **DTW word "len"**

# %%
ipd.Audio(len1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(len2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(len3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_len1 = librosa.load(len1)[0]
lib_len2 = librosa.load(len2)[0]
lib_len3 = librosa.load(len3)[0]

# %%
template_len1 = normalize_mfcc(librosa.feature.mfcc(y=lib_len1))
template_len2 = normalize_mfcc(librosa.feature.mfcc(y=lib_len2))
template_len3 = normalize_mfcc(librosa.feature.mfcc(y=lib_len3))

# %%
cost01_len, align01_len = librosa.sequence.dtw(template_len1, template_len2, metric=metric)
cost02_len, align02_len = librosa.sequence.dtw(template_len1, template_len3, metric=metric)

# %%
count_len = np.ones(len(template_len1[0]))

summ_len = template_len1.copy()

# %%
for pair_len in align01_len:
    t, q = pair_len
    count_len[t] += 1
    summ_len[:,t] += template_len2[:,q]

# %%
for pair_len in align02_len:
    t, q = pair_len
    count_len[t] += 1
    summ_len[:,t] += template_len3[:,q]

# %%
average_len = summ_len / count_len
average_len.shape
# Out:
# (20, 18)

# %%
average_template_len = average_len

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 2.8275891275575056

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 0.5679747392443374

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 2.538576803167558

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 0.07276942478734438

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 1.0260371862950821

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 4.5336835398680115

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 2.963253695101798

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_len, metric=metric)[0][-1,-1]
# Out:
# 4.591334045124729

# %% [markdown]
# **DTW word "nhay"**

# %%
ipd.Audio(nhay1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(nhay2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(nhay3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_nhay1 = librosa.load(nhay1)[0]
lib_nhay2 = librosa.load(nhay2)[0]
lib_nhay3 = librosa.load(nhay3)[0]

# %%
template_nhay1 = normalize_mfcc(librosa.feature.mfcc(y=lib_nhay1))
template_nhay2 = normalize_mfcc(librosa.feature.mfcc(y=lib_nhay2))
template_nhay3 = normalize_mfcc(librosa.feature.mfcc(y=lib_nhay3))

# %%
cost01_nhay, align01_nhay = librosa.sequence.dtw(template_nhay1, template_nhay2, metric=metric)
cost02_nhay, align02_nhay = librosa.sequence.dtw(template_nhay1, template_nhay3, metric=metric)

# %%
count_nhay = np.ones(len(template_nhay1[0]))

summ_nhay = template_nhay1.copy()

# %%
for pair_nhay in align01_nhay:
    t, q = pair_nhay
    count_nhay[t] += 1
    summ_nhay[:,t] += template_nhay2[:,q]

# %%
for pair_nhay in align02_nhay:
    t, q = pair_nhay
    count_nhay[t] += 1
    summ_nhay[:,t] += template_nhay3[:,q]

# %%
average_nhay = summ_nhay / count_nhay
average_nhay.shape
# Out:
# (20, 19)

# %%
average_template_nhay = average_nhay

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 2.4528540140971806

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 1.0862860045531328

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 1.7144949281755608

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 0.9870811163851003

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 0.13615941728068703

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 2.8774302383412973

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 2.0325660029664627

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_nhay, metric=metric)[0][-1,-1]
# Out:
# 3.32656847771967

# %% [markdown]
# **DTW word "phai"**

# %%
ipd.Audio(phai1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(phai2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(phai3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_phai1 = librosa.load(phai1)[0]
lib_phai2 = librosa.load(phai2)[0]
lib_phai3 = librosa.load(phai3)[0]

# %%
template_phai1 = normalize_mfcc(librosa.feature.mfcc(y=lib_phai1))
template_phai2 = normalize_mfcc(librosa.feature.mfcc(y=lib_phai2))
template_phai3 = normalize_mfcc(librosa.feature.mfcc(y=lib_phai3))

# %%
cost01_phai, align01_phai = librosa.sequence.dtw(template_phai1, template_phai2, metric=metric)
cost02_phai, align02_phai = librosa.sequence.dtw(template_phai1, template_phai3, metric=metric)

# %%
count_phai = np.ones(len(template_phai1[0]))

summ_phai = template_phai1.copy()

# %%
for pair_phai in align01_phai:
    t, q = pair_phai
    count_phai[t] += 1
    summ_phai[:,t] += template_phai2[:,q]

# %%
for pair_phai in align02_phai:
    t, q = pair_phai
    count_phai[t] += 1
    summ_phai[:,t] += template_phai3[:,q]

# %%
average_phai = summ_phai / count_phai
average_phai.shape
# Out:
# (20, 21)

# %%
average_template_phai = average_phai

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 3.691247827596618

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 3.7127102963995204

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 0.8980015917725407

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 4.151552376154331

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 2.198994022206432

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 0.24210736773827357

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 1.578673891549335

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_phai, metric=metric)[0][-1,-1]
# Out:
# 2.7976569976901087

# %% [markdown]
# **DTW word "trai"**

# %%
ipd.Audio(trai1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(trai2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(trai3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_trai1 = librosa.load(trai1)[0]
lib_trai2 = librosa.load(trai2)[0]
lib_trai3 = librosa.load(trai3)[0]

# %%
template_trai1 = normalize_mfcc(librosa.feature.mfcc(y=lib_trai1))
template_trai2 = normalize_mfcc(librosa.feature.mfcc(y=lib_trai2))
template_trai3 = normalize_mfcc(librosa.feature.mfcc(y=lib_trai3))

# %%
cost01_trai, align01_trai = librosa.sequence.dtw(template_trai1, template_trai2, metric=metric)
cost02_trai, align02_trai = librosa.sequence.dtw(template_trai1, template_trai3, metric=metric)

# %%
count_trai = np.ones(len(template_trai1[0]))

summ_trai = template_trai1.copy()

# %%
for pair_trai in align01_trai:
    t, q = pair_trai
    count_trai[t] += 1
    summ_trai[:,t] += template_trai2[:,q]

# %%
for pair_trai in align02_trai:
    t, q = pair_trai
    count_trai[t] += 1
    summ_trai[:,t] += template_trai3[:,q]

# %%
average_trai = summ_trai / count_trai
average_trai.shape
# Out:
# (20, 20)

# %%
average_template_trai = average_trai

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 2.289388246764342

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 2.652081261450652

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 1.5541282884647387

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 3.4033065942343708

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 1.9339505307932963

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 1.1773468851355329

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 0.1879134717304125

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_trai, metric=metric)[0][-1,-1]
# Out:
# 3.3942338270141676

# %% [markdown]
# **DTW word "xuong"**

# %%
ipd.Audio(xuong1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(xuong2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(xuong3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
lib_xuong1 = librosa.load(xuong1)[0]
lib_xuong2 = librosa.load(xuong2)[0]
lib_xuong3 = librosa.load(xuong3)[0]

# %%
template_xuong1 = normalize_mfcc(librosa.feature.mfcc(y=lib_xuong1))
template_xuong2 = normalize_mfcc(librosa.feature.mfcc(y=lib_xuong2))
template_xuong3 = normalize_mfcc(librosa.feature.mfcc(y=lib_xuong3))

# %%
cost01_xuong, align01_xuong = librosa.sequence.dtw(template_xuong1, template_xuong2, metric=metric)
cost02_xuong, align02_xuong = librosa.sequence.dtw(template_xuong1, template_xuong3, metric=metric)

# %%
count_xuong = np.ones(len(template_xuong1[0]))

summ_xuong = template_xuong1.copy()

# %%
for pair_xuong in align01_xuong:
    t, q = pair_xuong
    count_xuong[t] += 1
    summ_xuong[:,t] += template_xuong2[:,q]

# %%
for pair_xuong in align02_xuong:
    t, q = pair_xuong
    count_xuong[t] += 1
    summ_xuong[:,t] += template_xuong3[:,q]

# %%
average_xuong = summ_xuong / count_xuong
average_xuong.shape
# Out:
# (20, 25)

# %%
average_template_xuong = average_xuong

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/A/a1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 8.186713950136356

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/B/b1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 4.802626748704608

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Ban/ban1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 2.453447073332736

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Len/len1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 4.677434497529129

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Nhay/nhay1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 3.5668592966438233

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Phai/phai1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 3.0275751985110317

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Trai/trai1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 3.8424292568077205

# %%
librosa.sequence.dtw(normalize_mfcc(librosa.feature.mfcc(y=librosa.load('/content/Xuong/xuong1.wav')[0])), average_template_xuong, metric=metric)[0][-1,-1]
# Out:
# 0.14299460188369728
